# %%
import pandas as pd

# %%
 df = pd.read_csv('Police_Department_Incident_Reports__2018_to_Present_20250306.csv')

# %%
df.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 1  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 2  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
# 3  2023/02/15 03:00:00 AM    2023/02/15         03:00           2023
# 4  2023/03/13 11:26:00 AM    2023/03/13         11:26           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 1               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 2              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
# 3            Wednesday  2023/03/11 04:55:00 PM  125378606372      1253786
# 4               Monday  2023/03/13 01:37:00 PM  125419506244      1254195
#
#    Incident Number  CAD Number  ... Longitude Point Neighborhoods  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937595 entries, 0 to 937594
# Data columns (total 35 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   Incident Datetime                                     937595 non-null  object
#  1   Incident Date                                         937595 non-null  object
#  2   Incident Time                                         937595 non-null  object
#  3   Incident Year                                         937595 non-null  int64
#  4   Incident Day of Week                                  937595 non-null  object
#  5   Report Datetime                                       937595 non-null  object
#  6   Row ID                                                937595 non-null  int64
#  7   Incident ID                                           937595 non-null  int64
# ...

# %%
crimesin2024 = df.loc[df['Incident Year']==2024]

# %%
crimesin2024.head()
# Out:
#            Incident Datetime Incident Date Incident Time  Incident Year  \
# 1644  2024/09/05 06:15:00 AM    2024/09/05         06:15           2024
# 2273  2024/08/09 12:00:00 AM    2024/08/09         00:00           2024
# 2276  2024/12/12 12:06:00 PM    2024/12/12         12:06           2024
# 2277  2024/11/17 12:30:00 PM    2024/11/17         12:30           2024
# 2282  2024/11/28 02:00:00 PM    2024/11/28         14:00           2024
#
#      Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 1644             Thursday  2024/09/05 07:10:00 AM  142126304134      1421263
# 2273               Friday  2025/01/23 08:46:00 AM  145657206125      1456572
# 2276             Thursday  2025/01/23 05:00:00 PM  145667164080      1456671
# 2277               Sunday  2024/11/17 05:57:00 PM  144629707026      1446297
# 2282             Thursday  2024/11/28 03:28:00 PM  144630507026      1446305
#
#       Incident Number   CAD Number  ...   Longitude  \
# ...
